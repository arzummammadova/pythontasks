# %% [markdown]
#  Sprint_2a_task

# %%
# Sprint_2a_task


# 5, 10, 15, 20 rəqəmlərindən ibarət “rəqəmlər” adlı list/vector yaradın
reqemler=[5,10,15,20]
print(reqemler)
# Out:
# [5, 10, 15, 20]

# %%
# “rəqəmlər” listinin/vectorunun uzunluğunu tapın
print(len(reqemler))
# Out:
# 4

# %%
# 3) “rəqəmlər” listinə/vectoruna 25 elementini əlavə edin
reqemler.append(25)
print(reqemler)
# Out:
# [5, 10, 15, 20, 25]

# %%
# 4) “rəqəmlər” listinin/vectorunun 2-ci indeksinə 12 elementini əlavə edin
reqemler.insert(2,12)
reqemler
# Out:
# [5, 10, 12, 15, 20, 25]

# %%
# 5) 1, 2, 3 və 4, 5, 6 listlərini/vectorlarını birləşdirin
list1=[1,2,3]
list2=[4,5,6]
new=list1+list2
print(new)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# 6) “rəqəmlər” listindən/vectorundan 2-ci və 3-cü elementləri seçin
print(reqemler[2:4])
# Out:
# [12, 15]

# %%
# 7) “rəqəmlər” listinin/vectorunun ilk elementini 50 ilə əvəz edin
reqemler[0]=50
print(reqemler)
# Out:
# [50, 10, 12, 15, 20, 25]

# %%
# 8) “rəqəmlər” listində/vectorunda 19 elementinin olub-olmadığını yoxlayın
rəqəmlər = [3, 7, 12, 19, 25, 33]
if 19 in rəqəmlər:
    print("19 rəqəmlər listində mövcuddur.")
else:
    print("19 rəqəmlər listində mövcud deyil.")
# Out:
# 19 rəqəmlər listində mövcuddur.

# %%
# 9) "a", "b", "a", "c" listində/vectorunda "a" elementinin neçə dəfə təkrarlandığını tapın
alpha_list=["a","b","a","c"]
count=alpha_list.count("a")
print(f"a elementi {count} defe tekrarlanib")
# Out:
# a elementi 2 defe tekrarlanib

# %%
# 10) "x", "y", "x", "z" listindən/vectorundan "x" elementlərini silin
listt=["x","y","x","z"]
while "x" in listt:
  listt.remove("x")
print(listt)
# Out:
# ['y', 'z']

# %%
# 11) 7, 2, 9, 1 listini/vectorunu azalan sırayla sıralayın
vector=[7,2,9,1]
vector.sort(reverse=True)
print(vector)
# Out:
# [9, 7, 2, 1]

# %%
# 12) “rəqəmlər” listindən/vectorundan 10-dan böyük elementləri seçin

more10=[i for  i in reqemler if i>10]
print(more10)
# Out:
# [15, 20]

# %% [markdown]
# **Sprint_2b_task:**

# %%
# 1) 10, 20, 30, 40 elementlərindən ibarət s1 adlı series/vector yaradın
import pandas as pd
s1 = pd.Series([10, 20, 30, 40])

# %%
# 2) s1-ə 'w', 'x', 'y', 'z' indekslərini təyin edin
s1.index=['w','x','y','z']
print(s1)
# Out:
# w    10
# x    20
# y    30
# z    40
# dtype: int64

# %%
# 3) Python: {'p': 5, 'q': 10, 'r': 15} dictionary-dən s2 adlı Series yaradın
#     R: list(p = 5, q = 10, r = 15) listindən v2 adlı named vektor yaradın

data = {'p': 5, 'q': 10, 'r': 15}
s2 = pd.Series(data)

print(s2)
# Out:
# p     5
# q    10
# r    15
# dtype: int64

# %%
# 4) s2-dən 'q' indeksli elementi seçin
q_elementi=s2.loc['q']
print (q_elementi)
# Out:
# 10

# %%
# 5) s1-dən 25-dən böyük elementləri seçin
boyuk=s1[s1>25]
print(boyuk)
# Out:
# y    30
# z    40
# dtype: int64

# %%
# 6) s1-də 20-dən böyük elementləri 10-a bölün
morethan10=s1[s1>10]
divide10=morethan10/10
print(divide10)
# Out:
# x    2.0
# y    3.0
# z    4.0
# dtype: float64

# %%
# 7) ((1, 2), (3, 4)) listindən/vectorundan df1 adlı dataframe yaradın
data=[(1,2),(3,4)]
df1 = pd.DataFrame(data, columns=['A', 'B'])
print(df1)
# Out:
#    A  B
# 0  1  2
# 1  3  4

# %%
# 8) df1-ə ('r1', 'r2') sətir və ('c1', 'c2') sütun adlarını təyin edin
df1 = pd.DataFrame(data, columns=['c1', 'c2'])
df1.index=['r1','r2']
print(df1)
# Out:
#     c1  c2
# r1   1   2
# r2   3   4

# %%
# 9) Python: {'A': [1, 2], 'B': [3, 4]} dictionary-dən df2 yaradın
data = {'A': [1, 2], 'B': [3, 4]}
df2 = pd.DataFrame(data)

# %%
# 10) df2-də 'A' sütunu 1-dən böyük olan sətirləri seçin



filtered_df = df2[df2['A'] > 1]



print(filtered_df)
# Out:
#    A  B
# 1  2  4
